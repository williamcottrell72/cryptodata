# %% [markdown]
# # DEX Data Analysis
#
# Load and analyze DEX trading data from The Graph subgraphs.

# %%
import json
import os
import sys
from pathlib import Path

# Add project root to Python path
PROJECT_ROOT = Path(__file__).parent.parent if '__file__' in dir() else Path.cwd().parent
KUATO_DEV = Path.home() / 'git' / 'kuato_dev'

for path in [PROJECT_ROOT, KUATO_DEV]:
    if str(path) not in sys.path:
        sys.path.insert(0, str(path))

import pandas as pd
import plotly
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

# %%
def load_dex_data(subgraph: str, query_type: str) -> pd.DataFrame:
    """
    Load DEX data from the data directory as a pandas DataFrame.
    
    Args:
        subgraph: The subgraph name (e.g., 'uniswap_v3_ethereum', 'pancakeswap_v3_bsc')
        query_type: The query type ('pools', 'swaps', or 'tokens')
        
    Returns:
        pandas DataFrame with the query results
        
    Example:
        df = load_dex_data('uniswap_v3_ethereum', 'swaps')
    """
    data_path = PROJECT_ROOT / 'data' / subgraph / query_type / 'data.json'
    
    if not data_path.exists():
        raise FileNotFoundError(
            f"Data file not found: {data_path}\n"
            f"Run: python thegraph_dex_downloader.py --subgraph {subgraph} --query-type {query_type}"
        )
    
    with open(data_path, 'r') as f:
        data = json.load(f)
    
    df = pd.DataFrame(data)
    
    # Convert timestamp columns to datetime if present
    if 'timestamp' in df.columns:
        df['timestamp'] = pd.to_datetime(df['timestamp'], unit='s')
    if 'datetime' in df.columns:
        df['datetime'] = pd.to_datetime(df['datetime'])
    
    return df

# %%
def list_available_data() -> dict:
    """
    List all available downloaded data.
    
    Returns:
        Dictionary mapping subgraph names to lists of available query types
    """
    data_dir = PROJECT_ROOT / 'data'
    available = {}
    
    if not data_dir.exists():
        print("No data directory found. Run thegraph_dex_downloader.py first.")
        return available
    
    for subgraph_dir in data_dir.iterdir():
        if subgraph_dir.is_dir():
            query_types = []
            for query_dir in subgraph_dir.iterdir():
                if query_dir.is_dir() and (query_dir / 'data.json').exists():
                    query_types.append(query_dir.name)
            if query_types:
                available[subgraph_dir.name] = query_types
    
    return available

# Show available data
available = list_available_data()
if available:
    print("Available data:")
    for subgraph, query_types in available.items():
        print(f"  {subgraph}: {', '.join(query_types)}")
else:
    print("No data available yet. Run the downloader script first.")
# Out:
# Available data:
#   uniswap_v3_ethereum: swaps
#   uniswap_v3_arbitrum: swaps
#   pancakeswap_v3_bsc: pools
#   pancakeswap_v3_ethereum: swaps

# %% [markdown]
# ## Usage Example
#
# Load data by specifying the subgraph and query type:

# %%
# Example: Load data (uncomment and modify as needed)
# df_psp = load_dex_data('pancakeswap_v3_bsc', 'pools')
df = load_dex_data('uniswap_v3_ethereum', 'swaps')
df = df.assign(price = abs(df['amount0'] / df['amount1']))
df.head()
# Out:
#                                                   id  \
# 0  0xe9b0db62436a889471394bb46b4a3307cc9b12828a1b...
# 1  0x97ddb84f4acbb0433f8cd7e30c1cacff7dca7503d7c0...
# 2  0x02d52d8caef222aa9da34fefa3416f11b9b366240474...
# 3  0x2a82d0f1c872584940b84f271e119f342dcfa066f910...
# 4  0x9c5203f3ee2ddff0a2bf469181cf8be95e6015f61f63...
#
#                                              tx_hash block_number  \
# 0  0xe9b0db62436a889471394bb46b4a3307cc9b12828a1b...     23920030
# 1  0x97ddb84f4acbb0433f8cd7e30c1cacff7dca7503d7c0...     23920030
# 2  0x02d52d8caef222aa9da34fefa3416f11b9b366240474...     23920030
# 3  0x2a82d0f1c872584940b84f271e119f342dcfa066f910...     23920029
# 4  0x9c5203f3ee2ddff0a2bf469181cf8be95e6015f61f63...     23920028
#
#             timestamp            datetime  \
# 0 2025-12-01 17:09:59 2025-12-01 11:09:59
# 1 2025-12-01 17:09:59 2025-12-01 11:09:59
# 2 2025-12-01 17:09:59 2025-12-01 11:09:59
# 3 2025-12-01 17:09:47 2025-12-01 11:09:47
# 4 2025-12-01 17:09:35 2025-12-01 11:09:35
#
#                                       pool_id       pair       amount0  \
# 0  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  USDC/WETH    -10.500000
# 1  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  USDC/WETH -17461.007876
# 2  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  USDC/WETH    176.941596
# 3  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  USDC/WETH -20188.305480
# 4  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640  USDC/WETH  -2350.298369
#
#     amount1    amount_usd                                      sender  \
# 0  0.003840     10.506103  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad
# 1  6.383507  17468.001328  0xa836912dce3b96cb9f3f1bf2406d6491ed601f66
# 2 -0.064646    176.955587  0x66a9893cc07d91d95644aedd05d03f95e1dba8af
# 3  7.374830  20188.534900  0xfbd4cdb413e45a52e2c8312f670e9ce67e794c37
# 4  0.858169   2349.777992  0x365084b05fa7d5028346bd21d842ed0601bab5b8
#
#                                     recipient        price
# 0  0x3fc91a3afd70395cd496c647d5a6cc9d4b2b7fad  2734.344021
# 1  0xa836912dce3b96cb9f3f1bf2406d6491ed601f66  2735.331592
# 2  0x66a9893cc07d91d95644aedd05d03f95e1dba8af  2737.089833
# 3  0xfbd4cdb413e45a52e2c8312f670e9ce67e794c37  2737.460475
# 4  0x365084b05fa7d5028346bd21d842ed0601bab5b8  2738.735454

# %%
from src import feeds
instrument = "ETHUSD"
start_date = "20251130"
end_date = "20251201"
feed = feeds.PolygonAggregateFeed(symbol=instrument)
ds = feed.load_historical_dataset(
    start_date=start_date, end_date=end_date
)

# %%
df_poly = ds['close'].to_dataframe().reset_index()
df_poly['time'] = pd.DatetimeIndex(df_poly['timestamp']* 1000000)

# %%
df_merged = pd.merge_asof(df.sort_values(by='timestamp'), df_poly.drop(columns='timestamp'), left_on='timestamp', right_on='time')

# %%
df_final = df_merged[['time', 'close', 'price']].rename(columns={"price": "dex_price", "close": "cex_price"})
px.line(df_final, 'time', ['cex_price', 'dex_price'])

# %%
import numpy as np

def volatility(vals):
    delta = np.where((vals[:-1] >0)&(vals[1:] !=0)  , np.log(vals[1:]/vals[:-1]), 0)
    return np.std(delta) * 1e4

dex_volatility = volatility(df_final.dropna()['dex_price'].values)
cex_volatility = volatility(df_final.dropna()['cex_price'].values)
dex_volatility, cex_volatility
# Out:
# /var/folders/8t/2h1cpqn11lb6y123qycr9pg40000gn/T/ipykernel_67199/1025555533.py:4: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /var/folders/8t/2h1cpqn11lb6y123qycr9pg40000gn/T/ipykernel_67199/1025555533.py:4: RuntimeWarning:
#
# divide by zero encountered in log
# (13.975006319794238, 4.401090453870522)

# %%
dex_prices = df_final['dex_price'].values
cex_prices = df_final['cex_price'].values

dex_returns = np.where(dex_prices[:-1] !=0, np.log(dex_prices[1:] / dex_prices[:-1]), 0)
dex_returns = np.concatenate([[0], dex_returns])

feature1 = dex_prices - cex_prices

mask = (np.isfinite(dex_returns)) * (np.isfinite(feature1))
cex_to_dex = np.corrcoef(dex_returns[mask], feature1[mask])[0,1]
print(f"CEX -> DEX prediction corr: {cex_to_dex}")
# Out:
# CEX -> DEX prediction corr: 0.4361794380971847
# /var/folders/8t/2h1cpqn11lb6y123qycr9pg40000gn/T/ipykernel_67199/2398849006.py:4: RuntimeWarning:
#
# divide by zero encountered in divide
#
# /var/folders/8t/2h1cpqn11lb6y123qycr9pg40000gn/T/ipykernel_67199/2398849006.py:4: RuntimeWarning:
#
# divide by zero encountered in log

# %%
dex_prices = df_final['cex_price'].values
cex_prices = df_final['dex_price'].values

dex_returns = np.where(dex_prices[:-1] !=0, np.log(dex_prices[1:] / dex_prices[:-1]), 0)
dex_returns = np.concatenate([[0], dex_returns])

feature1 = dex_prices - cex_prices

mask = (np.isfinite(dex_returns)) * (np.isfinite(feature1))
dex_to_cex = np.corrcoef(dex_returns[mask], feature1[mask])[0,1]
print(f"DEX -> CEX prediction corr: {dex_to_cex}")
# Out:
# DEX -> CEX prediction corr: 0.031543264677086784
